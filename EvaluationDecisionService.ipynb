# %%
import sys
import json
import logging
from spyne import rpc, ServiceBase, Unicode, ComplexModel, Application
from spyne.protocol.soap import Soap11
from spyne.server.wsgi import WsgiApplication
from spyne.util.wsgi_wrapper import run_twisted

logging.basicConfig(level=logging.DEBUG)

class DictionnaryItem(ComplexModel):
    __namespace__ = 'information_extraction'
    key = Unicode
    value = Unicode

class EvaluationDecisionService(ServiceBase):
    @rpc(DictionnaryItem, _returns=DictionnaryItem)
    def evaluationScore(ctx, LoanMap):
        try:
            LoanMap.value = json.loads(LoanMap.value.replace("'", "\""))
        except json.JSONDecodeError as e:
            return DictionnaryItem(key="Erreur", value=f"Erreur de conversion : {e}")

        montant_pret = float(LoanMap.value["Montant du Prêt Demandé"].replace('EUR', '').strip())
        duree = int(LoanMap.value["Durée du Prêt"].replace('ans', '').strip())
        revenu_mensuel = float(LoanMap.value["Revenu Mensuel"].replace('EUR', '').strip())
        depense = float(LoanMap.value["Dépenses Mensuelles"].replace('EUR', '').strip())
        score = LoanMap.value["score"]

        # Calculer le remboursement et le taux d'endettement
        taux_interet = 0.03
        remboursement = (montant_pret * taux_interet * (1 + taux_interet)**duree) / ((1 + taux_interet)**(duree - 1))
        taux_endettement = (remboursement / revenu_mensuel) * 100

        # Évaluer la décision
        if remboursement + depense < revenu_mensuel and score > 50 and taux_endettement < 40:
            description = "Vous correspondez à tous les critères. Nous acceptons votre crédit."
            response = {"Réponse banque": True, "Description": description}
        else:
            description = "Nous ne pouvons pas accepter le crédit car "
            if remboursement + depense >= revenu_mensuel:
                description += "vos dépenses mensuelles sont trop élevées."
            if score <= 50:
                description += " Votre score de crédit est trop faible."
            if taux_endettement >= 40:
                description += " Le ratio de remboursement est trop risqué."
            response = {"Réponse banque": False, "Description": description}

        return DictionnaryItem(key="Réponse banque", value=json.dumps(response))

application = Application([EvaluationDecisionService],
                          tns='evaluation.decision.EvaluationDecisionService',
                          in_protocol=Soap11(),
                          out_protocol=Soap11())

if __name__ == '__main__':
    wsgi_app = WsgiApplication(application)
    sys.exit(run_twisted([(wsgi_app, b'EvaluationDecisionService')], 8008))
# Out:
# DEBUG:spyne.model.complex:Got bases for DictionnaryItem from meta: (<class 'spyne.model.complex.ComplexModel'>,)
# DEBUG:spyne.model.complex:Got bases for evaluationScore from meta: (<class 'spyne.model.complex.ComplexModel'>,)
# DEBUG:spyne.model.complex:Got bases for evaluationScoreResponse from meta: (<class 'spyne.model.complex.ComplexModel'>,)
# INFO:spyne.application:Initializing application {evaluation.decision.EvaluationDecisionService}Application...
# DEBUG:spyne.interface._base:populating __main__.EvaluationDecisionService types...
# DEBUG:spyne.interface._base:  enumerating classes for method 'evaluationScore'
# DEBUG:spyne.interface._base:    adding class "<class 'spyne.model.complex.evaluationScore'>" for '{evaluation.decision.EvaluationDecisionService}evaluationScore'
# DEBUG:spyne.interface._base:    adding evaluationScore.LoanMap = <class '__main__.DictionnaryItem'>
# DEBUG:spyne.interface._base:    adding class "<class '__main__.DictionnaryItem'>" for '{information_extraction}DictionnaryItem'
# DEBUG:spyne.interface._base:    adding DictionnaryItem.key = <class 'spyne.model.primitive.string.Unicode'>
# DEBUG:spyne.interface._base:    adding class "<class 'spyne.model.primitive.string.Unicode'>" for '{http://www.w3.org/2001/XMLSchema}string'
# DEBUG:spyne.interface._base:    adding DictionnaryItem.value = <class 'spyne.model.primitive.string.Unicode'>
# DEBUG:spyne.interface._base:    importing 'information_extraction' to 'evaluation.decision.EvaluationDecisionService' for evaluationScore.LoanMap(<class '__main__.DictionnaryItem'>)
# DEBUG:spyne.interface._base:    adding class "<class 'spyne.model.complex.evaluationScoreResponse'>" for '{evaluation.decision.EvaluationDecisionService}evaluationScoreResponse'
# DEBUG:spyne.interface._base:    adding evaluationScoreResponse.evaluationScoreResult = <class '__main__.DictionnaryItem'>
# DEBUG:spyne.interface._base:populating '__main__.EvaluationDecisionService' routes...
# DEBUG:spyne.interface._base:  adding method EvaluationDecisionService.evaluationScore to match '{evaluation.decision.EvaluationDecisionService}evaluationScore' tag.
# DEBUG:spyne.interface._base:From this point on, you're not supposed to make any changes to the class and method structure of the exposed services.
# DEBUG:spyne.util.appreg:Registering <spyne.application.Application object at 0x0000028C969C9190> as ('evaluation.decision.EvaluationDecisionService', 'Application')
# INFO:root:registering static folder 'c:\\Users\\21627\\Desktop\\TP' on /
# INFO:root:registering <spyne.server.wsgi.WsgiApplication object at 0x0000028C96AB26D0> on /b'EvaluationDecisionService'
# INFO:root:listening on: 0.0.0.0:8008
# DEBUG:spyne.server.wsgi:Add http header 'accept_encoding' = ['identity']
# DEBUG:spyne.server.wsgi:Add http header 'host' = ['localhost:8008']
# DEBUG:spyne.server.wsgi:Add http header 'user_agent' = ['Python-urllib/3.11']
# DEBUG:spyne.server.wsgi:Add http header 'connection' = ['close']
# DEBUG:spyne:gc.collect() took around 40ms.
# DEBUG:spyne.server.wsgi:Add http header 'accept_encoding' = ['identity']
# DEBUG:spyne.server.wsgi:Add http header 'content_length' = ['516']
# DEBUG:spyne.server.wsgi:Add http header 'host' = ['localhost:8008']
# DEBUG:spyne.server.wsgi:Add http header 'user_agent' = ['Python-urllib/3.11']
# DEBUG:spyne.server.wsgi:Add http header 'content_type' = ['text/xml; charset=utf-8']
# DEBUG:spyne.server.wsgi:Add http header 'soapaction' = ['"evaluationScore"']
# DEBUG:spyne.server.wsgi:Add http header 'connection' = ['close']
# DEBUG:spyne.protocol.soap.soap11:ValueError: Deserializing from unicode strings with encoding declaration is not supported by lxml.
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 0
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 1
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 1
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 2
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 2
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 2
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 0
# DEBUG:spyne.protocol._base:PMORPH Skipped: <spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> is NOT polymorphic
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 1
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 1
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 1
# DEBUG:spyne.protocol._base:PMORPH Skipped: <spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> is NOT polymorphic
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 2
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 2
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 2
# DEBUG:spyne.protocol._base:PMORPH Skipped: <spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> is NOT polymorphic
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:PMORPH Skipped: <spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> is NOT polymorphic
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne:gc.collect() took around 40ms.
# DEBUG:spyne.server.wsgi:Add http header 'accept_encoding' = ['identity']
# DEBUG:spyne.server.wsgi:Add http header 'content_length' = ['517']
# DEBUG:spyne.server.wsgi:Add http header 'host' = ['localhost:8008']
# DEBUG:spyne.server.wsgi:Add http header 'user_agent' = ['Python-urllib/3.11']
# DEBUG:spyne.server.wsgi:Add http header 'content_type' = ['text/xml; charset=utf-8']
# DEBUG:spyne.server.wsgi:Add http header 'soapaction' = ['"evaluationScore"']
# DEBUG:spyne.server.wsgi:Add http header 'connection' = ['close']
# DEBUG:spyne.protocol.soap.soap11:ValueError: Deserializing from unicode strings with encoding declaration is not supported by lxml.
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C967F8510> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:PMORPH Skipped: <spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> is NOT polymorphic
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:PMORPH Skipped: <spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> is NOT polymorphic
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:PMORPH Skipped: <spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> is NOT polymorphic
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:PMORPH Skipped: <spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> is NOT polymorphic
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne.protocol._base:<spyne.protocol.soap.soap11.Soap11 object at 0x0000028C969B7750> attrcache size: 3
# DEBUG:spyne:gc.collect() took around 40ms.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\21627\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
